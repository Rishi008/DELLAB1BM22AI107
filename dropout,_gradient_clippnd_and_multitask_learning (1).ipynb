# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np

torch.manual_seed(0)
X = torch.rand(1000, 10)
y_class = (torch.sum(X, dim=1) > 5).float().unsqueeze(1)
y_reg = torch.sum(X, dim=1).unsqueeze(1)


train_data = TensorDataset(X[:800], y_class[:800], y_reg[:800])
val_data = TensorDataset(X[800:], y_class[800:], y_reg[800:])
train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
val_loader = DataLoader(val_data, batch_size=64)


class MultitaskNN(nn.Module):
    def __init__(self):
        super(MultitaskNN, self).__init__()
        self.shared = nn.Sequential(
            nn.Linear(10, 64),
            nn.ReLU(),
            nn.Dropout(0.3)
        )
        self.classifier = nn.Sequential(
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )
        self.regressor = nn.Sequential(
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1)
        )

    def forward(self, x):
        shared_output = self.shared(x)
        class_output = self.classifier(shared_output)
        reg_output = self.regressor(shared_output)
        return class_output, reg_output

model = MultitaskNN()
criterion_class = nn.BCELoss()
criterion_reg = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

def train_with_early_stopping(model, train_loader, val_loader, num_epochs=50, patience=5, clip_value=1.0):
    best_val_loss = float('inf')
    patience_counter = 0

    for epoch in range(num_epochs):

        model.train()
        train_loss = 0.0
        for inputs, y_class, y_reg in train_loader:

            class_preds, reg_preds = model(inputs)
            loss_class = criterion_class(class_preds, y_class)
            loss_reg = criterion_reg(reg_preds, y_reg)
            loss = loss_class + loss_reg  # Combined multitask loss

            optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), clip_value)
            optimizer.step()

            train_loss += loss.item()


        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for inputs, y_class, y_reg in val_loader:
                class_preds, reg_preds = model(inputs)
                loss_class = criterion_class(class_preds, y_class)
                loss_reg = criterion_reg(reg_preds, y_reg)
                loss = loss_class + loss_reg
                val_loss += loss.item()


        train_loss /= len(train_loader)
        val_loss /= len(val_loader)

        print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}")


        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            best_model_state = model.state_dict()
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered!")
                model.load_state_dict(best_model_state)
                break

train_with_early_stopping(model, train_loader, val_loader)
# Out:
# Epoch 1/50, Train Loss: 23.8984, Val Loss: 22.4151
# Epoch 2/50, Train Loss: 20.2819, Val Loss: 17.7738
# Epoch 3/50, Train Loss: 14.7336, Val Loss: 11.0546
# Epoch 4/50, Train Loss: 7.6032, Val Loss: 3.7912
# Epoch 5/50, Train Loss: 1.9440, Val Loss: 0.8620
# Epoch 6/50, Train Loss: 1.2792, Val Loss: 0.7686
# Epoch 7/50, Train Loss: 1.1223, Val Loss: 0.7181
# Epoch 8/50, Train Loss: 1.0304, Val Loss: 0.6842
# Epoch 9/50, Train Loss: 0.9664, Val Loss: 0.6549
# Epoch 10/50, Train Loss: 0.9415, Val Loss: 0.6416
# Epoch 11/50, Train Loss: 0.9081, Val Loss: 0.6136
# Epoch 12/50, Train Loss: 0.8953, Val Loss: 0.6035
# Epoch 13/50, Train Loss: 0.8751, Val Loss: 0.5847
# Epoch 14/50, Train Loss: 0.8232, Val Loss: 0.5536
# Epoch 15/50, Train Loss: 0.8087, Val Loss: 0.5579
# Epoch 16/50, Train Loss: 0.8195, Val Loss: 0.5306
# Epoch 17/50, Train Loss: 0.8079, Val Loss: 0.5551
# Epoch 18/50, Train Loss: 0.7953, Val Loss: 0.5066
# Epoch 19/50, Train Loss: 0.7416, Val Loss: 0.4924
# Epoch 20/50, Train Loss: 0.7484, Val Loss: 0.4790
# Epoch 21/50, Train Loss: 0.7324, Val Loss: 0.4713
# Epoch 22/50, Train Loss: 0.7015, Val Loss: 0.4915
# Epoch 23/50, Train Loss: 0.7377, Val Loss: 0.4450
# Epoch 24/50, Train Loss: 0.7018, Val Loss: 0.4314
# Epoch 25/50, Train Loss: 0.6596, Val Loss: 0.4242
# Epoch 26/50, Train Loss: 0.6820, Val Loss: 0.4180
# Epoch 27/50, Train Loss: 0.6783, Val Loss: 0.4128
# Epoch 28/50, Train Loss: 0.6662, Val Loss: 0.4324
# Epoch 29/50, Train Loss: 0.6419, Val Loss: 0.3965
# Epoch 30/50, Train Loss: 0.6257, Val Loss: 0.3819
# Epoch 31/50, Train Loss: 0.6350, Val Loss: 0.3614
# Epoch 32/50, Train Loss: 0.5650, Val Loss: 0.3514
# Epoch 33/50, Train Loss: 0.5757, Val Loss: 0.3604
# Epoch 34/50, Train Loss: 0.5903, Val Loss: 0.3304
# Epoch 35/50, Train Loss: 0.5759, Val Loss: 0.3527
# Epoch 36/50, Train Loss: 0.5803, Val Loss: 0.3276
# Epoch 37/50, Train Loss: 0.5432, Val Loss: 0.3238
# Epoch 38/50, Train Loss: 0.5535, Val Loss: 0.3513
# Epoch 39/50, Train Loss: 0.5309, Val Loss: 0.3155
# Epoch 40/50, Train Loss: 0.5189, Val Loss: 0.2915
# Epoch 41/50, Train Loss: 0.5424, Val Loss: 0.2993
# Epoch 42/50, Train Loss: 0.5603, Val Loss: 0.2885
# Epoch 43/50, Train Loss: 0.5266, Val Loss: 0.2842
# Epoch 44/50, Train Loss: 0.5164, Val Loss: 0.2798
# Epoch 45/50, Train Loss: 0.5020, Val Loss: 0.2843
# Epoch 46/50, Train Loss: 0.4587, Val Loss: 0.2833
# Epoch 47/50, Train Loss: 0.4643, Val Loss: 0.2676
# Epoch 48/50, Train Loss: 0.4713, Val Loss: 0.2472
# Epoch 49/50, Train Loss: 0.4583, Val Loss: 0.2514
# Epoch 50/50, Train Loss: 0.4395, Val Loss: 0.2505
